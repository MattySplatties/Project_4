# %%
import pandas as pd
file= 'JC-202312-citibike-tripdata.csv'
cb2024 = pd.read_csv(file)
cb2024
# Out:
#                 ride_id rideable_type           started_at  \
# 0      DAE3C13A5FAAB089  classic_bike  2023-12-29 16:02:20
# 1      1EC6BE46ACF2DE11  classic_bike  2023-12-06 01:58:32
# 2      105CA439B9CBF57C  classic_bike  2023-12-06 20:15:11
# 3      DC1C46F6090FA1DB  classic_bike  2023-12-09 13:54:19
# 4      04EAEAAD6D32A664  classic_bike  2023-12-02 17:30:34
# ...                 ...           ...                  ...
# 58675  7E862701EE7A6A03  classic_bike  2023-12-20 17:55:41
# 58676  DFAF91AB91BE25DB  classic_bike  2023-12-13 14:36:43
# 58677  AEE7B49E6EDFAE6F  classic_bike  2023-12-18 16:40:00
# 58678  A38E98956AD72EFB  classic_bike  2023-12-02 13:42:51
# 58679  F16E0B969D877368  classic_bike  2023-12-19 16:30:13
#
#                   ended_at start_station_name start_station_id  \
# 0      2023-12-29 16:10:17       Brunswick St            JC023
# 1      2023-12-06 02:04:48       Brunswick St            JC023
# 2      2023-12-06 20:21:02       Brunswick St            JC023
# ...

# %%
cb2024.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
cb2024.info
# Out:
# <bound method DataFrame.info of                 ride_id rideable_type           started_at  \
# 0      DAE3C13A5FAAB089  classic_bike  2023-12-29 16:02:20
# 1      1EC6BE46ACF2DE11  classic_bike  2023-12-06 01:58:32
# 2      105CA439B9CBF57C  classic_bike  2023-12-06 20:15:11
# 3      DC1C46F6090FA1DB  classic_bike  2023-12-09 13:54:19
# 4      04EAEAAD6D32A664  classic_bike  2023-12-02 17:30:34
# ...                 ...           ...                  ...
# 58675  7E862701EE7A6A03  classic_bike  2023-12-20 17:55:41
# 58676  DFAF91AB91BE25DB  classic_bike  2023-12-13 14:36:43
# 58677  AEE7B49E6EDFAE6F  classic_bike  2023-12-18 16:40:00
# 58678  A38E98956AD72EFB  classic_bike  2023-12-02 13:42:51
# 58679  F16E0B969D877368  classic_bike  2023-12-19 16:30:13
#
#                   ended_at start_station_name start_station_id  \
# 0      2023-12-29 16:10:17       Brunswick St            JC023
# 1      2023-12-06 02:04:48       Brunswick St            JC023
# ...

# %%
cb2024['end_lng'].unique()
# looking for values that Tableau is not recognizing
# Out:
# array([-74.06661093, -74.0524783 , -74.04288411, -74.0439909 ,
#        -74.03434396, -74.04595256, -74.0625    , -74.04241204,
#        -74.03097   , -74.03329163, -74.05      , -74.06      ,
#        -74.04969156, -74.03852552, -74.02886541, -74.064437  ,
#        -74.07195926, -73.9503    , -74.03308198, -74.03586477,
#        -74.03450087, -74.0404433 , -74.00277668, -74.05727148,
#        -73.97087984, -74.04630454, -74.04879034, -74.06285852,
#        -74.04696375, -74.034234  , -74.02435273, -74.03223306,
#        -74.0836394 , -74.04772662, -73.96316   , -74.03511107,
#        -74.03768331, -74.03891444, -74.05038893, -74.0354826 ,
#        -74.03841153, -74.03030455, -74.00247214, -73.99103969,
#        -74.02778059, -74.0337589 , -74.0789    , -74.07      ,
#        -74.04      ,          nan, -74.03      , -74.03571   ,
#        -74.0316    , -74.04004097, -74.07106072, -74.05950308,
#        -74.032453  , -74.071455  , -73.986923  , -74.04309   ,
# ...

# %%
cb2024['start_lng'].unique()
# Out:
# array([-74.0505501 , -74.050686  , -74.05063903, ..., -74.04048681,
#        -74.04047012, -74.03440404])

# %%
len(cb2024['start_lng'].unique()), len(cb2024['end_lng'].unique())
# counts
# Out:
# (27347, 187)

# %%
len(cb2024['start_lat'].unique()), len(cb2024['end_lat'].unique())
# Out:
# (27034, 183)

# %%
cb2024['end_lat'].unique()
# Out:
# array([40.71435837, 40.7376037 , 40.72165072, 40.7443187 , 40.71636596,
#        40.72333159, 40.73367   , 40.716615  , 40.73736   , 40.75188939,
#        40.74      , 40.71      , 40.71539114, 40.71241882, 40.73721535,
#        40.73100889, 40.72572614, 40.67428   , 40.73915273, 40.74994325,
#        40.74439783, 40.74871595, 40.76087502, 40.74590997, 40.6729679 ,
#        40.72152515, 40.72568548, 40.71346383, 40.73520838, 40.7192517 ,
#        40.75296063, 40.74265933, 40.7182113 , 40.71848892, 40.64958   ,
#        40.74225798, 40.71517768, 40.7183552 , 40.72601173, 40.7242941 ,
#        40.74790721, 40.73593758, 40.71939226, 40.73972989, 40.73698222,
#        40.7272235 , 40.71113   , 40.73      ,         nan, 40.73743   ,
#        40.75409   , 40.74313994, 40.72755147, 40.73496102, 40.74816121,
#        40.72210379, 40.734232  , 40.72      , 40.71941   , 40.71458404,
#        40.75453   , 40.72528911, 40.74313283, 40.7241765 , 40.7236589 ,
# ...

# %%
cb2024.describe()
# Out:
#           start_lat     start_lng       end_lat       end_lng
# count  58680.000000  58680.000000  58638.000000  58638.000000
# mean      40.732804    -74.040155     40.732712    -74.039773
# std        0.012044      0.012062      0.012173      0.012153
# min       40.706575    -74.086826     40.645070    -74.140000
# 25%       40.721630    -74.045572     40.721525    -74.044247
# 50%       40.735938    -74.037683     40.735938    -74.036904
# 75%       40.742618    -74.030970     40.742659    -74.030970
# max       40.779868    -74.000990     40.796935    -73.926020

# %%
#https://stackoverflow.com/questions/27754891/check-if-single-cell-value-is-nan-in-pandas# 
cb2024[cb2024.isnull().any(1)]
# Out:
# C:\Users\Sch\AppData\Local\Temp\ipykernel_18208\3478883945.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   cb2024[cb2024.isnull().any(1)]
#                 ride_id rideable_type           started_at  \
# 65     8E26A1B1266BE7D4  classic_bike  2023-12-09 18:53:34
# 66     0ED7A1364FAA7491  classic_bike  2023-12-08 12:50:17
# 500    C2232AF6A99B91F6  classic_bike  2023-12-13 09:56:14
# 501    BBE29655E4F56F16  classic_bike  2023-12-11 15:31:13
# 502    7468D4CCC89D9F79  classic_bike  2023-12-11 12:51:54
# ...                 ...           ...                  ...
# 53388  8C1705634913B6E7  classic_bike  2023-12-18 14:12:25
# 55558  EF861287AFC29122  classic_bike  2023-12-13 07:42:49
# 55559  5C46CC1B233A9EE8  classic_bike  2023-12-08 08:13:25
# 57308  F9508E6CFB511D70  classic_bike  2023-12-10 12:18:10
# 57570  B9D3FDD2931A78D3  classic_bike  2023-12-27 05:21:37
#
# ...

# %%
len(cb2024[cb2024.isnull().any(1)])
# Out:
# C:\Users\Sch\AppData\Local\Temp\ipykernel_18208\3931663721.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   len(cb2024[cb2024.isnull().any(1)])
# 242
